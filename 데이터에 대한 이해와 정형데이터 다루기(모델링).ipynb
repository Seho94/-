# %%
from IPython.display import Image

# %% [markdown]
# # DIKW 구분 예제

# %%
Image("워크샵(1).png")

# %% [markdown]
# # ERD 그려보기 예제

# %%
Image("워크샵(2).png")

# %% [markdown]
# # ERD 해석하기 예제

# %%
Image("워크샵(3).png")

# %% [markdown]
# # 집이라는 소재를 통해 개체 도출 후 ERD 그려보기

# %%
Image("워크샵(4).png")
